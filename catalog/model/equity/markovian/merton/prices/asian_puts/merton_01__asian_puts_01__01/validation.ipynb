# %% [markdown]
# # Merton / Asian put
#
# Persisted independent validation of `merton_01__asian_puts_01__01`. The notebook only reads the report produced by the model/product validator; it never reruns Premia or QuantLib.

# %%
from pathlib import Path
import sys

project_root = next(
    parent for parent in (Path.cwd(), *Path.cwd().parents)
    if (parent / "CMakeLists.txt").is_file()
)
sys.path.insert(0, str(project_root))

from validation.reporting import display_validation_report, load_validation_report

dataset = project_root / "datasets/model/equity/markovian/merton/prices/asian_puts/merton_01__asian_puts_01__01.json"
report_path = project_root / "catalog/model/equity/markovian/merton/prices/asian_puts/merton_01__asian_puts_01__01/validation_report.json"

report = load_validation_report(report_path, dataset)
display_validation_report(report)
# Out:
# Core validation: PASS
# dataset                            : merton_01__asian_puts_01__01
# reference                          : Premia (specialized pricer)
# pricing method                     : AP_Asian_FMM_Mer call + arithmetic-average put-call parity (52 monitoring dates; 1,024 integration points, 4,096-point deterministic refinement when required)
# tolerance                          : 2e-05 absolute + 0.002 relative + 5 combined standard errors
# rows                               : 900
# accepted without special treatment : 900
# accepted after special treatment   : 0
# failed                             : 0
# mean signed price gap              : 2.189647e-04
# mean absolute price gap            : 6.361404e-04
# maximum absolute price gap         : 4.212367e-03 (row 000857)
# higher / lower / equal             : 581 / 319 / 0
# systematic bias                    : yes
# ...
