# %% [markdown]
# # Black-Scholes / Lookback Option
#
# Persisted independent validation of `black_scholes_01__lookback_options_01__01`. The notebook only reads the report produced by the model/product validator; it never reruns Premia or QuantLib.

# %%
from pathlib import Path
import sys

project_root = next(
    parent for parent in (Path.cwd(), *Path.cwd().parents)
    if (parent / "CMakeLists.txt").is_file()
)
sys.path.insert(0, str(project_root))

from validation.reporting import display_validation_report, load_validation_report

dataset = project_root / "datasets/price/equity/black_scholes/lookback_options/black_scholes_01__lookback_options_01__01.json"
report_path = project_root / "catalog/price/equity/black_scholes/lookback_options/black_scholes_01__lookback_options_01__01/validation_report.json"

report = load_validation_report(report_path, dataset)
display_validation_report(report)
# Out:
# Core validation: PASS
# dataset                            : black_scholes_01__lookback_options_01__01
# reference                          : Premia (specialized pricer)
# pricing method                     : CF_Fixed_CallLookBack
# tolerance                          : 1e-5 absolute + 5e-5 relative + 5 combined standard errors
# rows                               : 900
# accepted without special treatment : 900
# special rows                       : 0
# failed                             : 0
# mean signed price gap              : -8.293788e-03
# mean absolute price gap            : 8.293804e-03
# maximum absolute price gap         : 2.352587e-02 (row 000710)
# higher / lower / equal             : 2 / 898 / 0
# systematic bias                    : yes
# bias explanation                   : expected; a discrete maximum cannot exceed the continuous maximum
#
# Stress validation: PASS
# dataset                            : black_scholes_01__lookback_options_01__01
# ...
