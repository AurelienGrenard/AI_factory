# %% [markdown]
# # Black-Scholes / Double Knock Out Put
#
# Persisted independent validation of `black_scholes_01__double_knock_out_puts_01__01`. The notebook only reads the report produced by the model/product validator; it never reruns Premia or QuantLib.

# %%
from pathlib import Path
import sys

project_root = next(
    parent for parent in (Path.cwd(), *Path.cwd().parents)
    if (parent / "CMakeLists.txt").is_file()
)
sys.path.insert(0, str(project_root))

from validation.reporting import display_validation_report, load_validation_report

dataset = project_root / "datasets/price/equity/black_scholes/double_knock_out_puts/black_scholes_01__double_knock_out_puts_01__01.json"
report_path = project_root / "catalog/price/equity/black_scholes/double_knock_out_puts/black_scholes_01__double_knock_out_puts_01__01/validation_report.json"

report = load_validation_report(report_path, dataset)
display_validation_report(report)
# Out:
# Core validation: PASS
# dataset                            : black_scholes_01__double_knock_out_puts_01__01
# reference                          : Premia (specialized pricer)
# tolerance                          : 1e-5 absolute + 5e-5 relative + 5 combined standard errors
# rows                               : 900
# accepted without special treatment : 900
# special rows                       : 0
# failed                             : 0
# mean signed price gap              : 7.559826e-04
# mean absolute price gap            : 7.565729e-04
# maximum absolute price gap         : 7.901915e-03 (row 000880)
# higher / lower / equal             : 857 / 43 / 0
# systematic bias                    : yes
# bias explanation                   : expected; discrete monitoring knocks out fewer paths than continuous monitoring
#
# Stress validation: PASS
# dataset                            : black_scholes_01__double_knock_out_puts_01__01
# ...
