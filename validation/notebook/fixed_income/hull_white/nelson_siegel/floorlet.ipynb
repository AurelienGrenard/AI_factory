# %% [markdown]
# # Hull-White / Nelson-Siegel / Floorlet
#
# QuantLib validation snapshot for `hull_white_01__nelson_siegel_01__floorlets_01__01`.
#
# **Status:** PASS - 1,000 / 1,000 rows accepted
# **Validation date:** 2026-08-03
# **Price dataset:** `datasets/price/fixed_income/hull_white/nelson_siegel/floorlets/hull_white_01__nelson_siegel_01__floorlets_01__01.json`

# %% [markdown]
# ## Reference method
#
# **CUDA pricing:** `launch_hull_white_nelson_siegel_floorlet_cuda` in `src/model/fixed_income/hull_white/nelson_siegel/floorlet.cu`
# **QuantLib reference:** `ql.HullWhite.discountBondOption(ql.Option.Call, ...)` through the floorlet-to-bond-call identity
# **Validator:** `validation/quantlib/model/fixed_income/hull_white/nelson_siegel/floorlet.py`
# **Shared reference code:** `_rate_option_price` in `validation/quantlib/rate_option.py`
# **Acceptance:** absolute `5e-7` plus relative `5e-5`

# %% [markdown]
# ## Metrics
#
# | Metric | Value |
# |---|---:|
# | Accepted rows | 1,000 / 1,000 |
# | Mean signed error | 2.000e-09 |
# | Mean absolute error | 3.061e-08 |
# | Root mean squared error | 4.603e-08 |
# | Maximum absolute error | 2.157e-07 (row 000543) |
# | CUDA higher / lower / equal | 511 / 489 / 0 |
# | Systematic bias | No |
#
# > This is a deterministic closed-form comparison. The remaining differences are consistent with the CUDA FP32 implementation.

# %% [markdown]
# ## Reproduce
#
# Run from the project root:
#
# ```bash
# python3 -m validation.quantlib.model.fixed_income.hull_white.nelson_siegel.floorlet \
#   datasets/price/fixed_income/hull_white/nelson_siegel/floorlets/hull_white_01__nelson_siegel_01__floorlets_01__01.json
# ```
